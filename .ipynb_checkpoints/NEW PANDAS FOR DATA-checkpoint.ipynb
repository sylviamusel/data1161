# %% [markdown]
# # Pandas

# %% [markdown]
# # 1. INSTALLATION STUFF
#
# `imports`, you've seen this before!

# %%
#pip install matplotlib numpy pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from datetime import datetime

# %% [markdown]
# Some magic that tells jupyter to put graphs and things in the notebook instead of the default behaviour which is to save it as a file.

# %%
# %matplotlib inline

# %% [markdown]
# Set the size of the plots that will come out when we ask for them. Annoyingly, these are in inches. Whatever an "inch" is

# %%
plt.rcParams['figure.figsize'] = (10, 5)

# %% [markdown]
# saved_style_state = matplotlib.rcParams.copy() #give us a style state to go back to

# %% [markdown]
# # Shark Attacks

# %% [markdown]
# # Data Project
#
# Analysing the Shark Research Institute's dataset. The goal of this dataset is to inform people about the risks associated with coastal water activities, and to improve shark/human relations by educating people in factors that contribute to shark attacks.

# %% [markdown]
# ## 1. Understanding my data

# %% [markdown]
# # 2. LOAD DATA SET
# Analysing the Shark Research Institute's dataset. The goal of this dataset is to inform people about the risks associated with coastal water activities, and to improve shark/human relations by educating people in factors that contribute to shark attacks.

# %%
filepath = "GSAF5.xls.xlsx"

sad = pd.read_excel(filepath)
print("done")
# Out:
# done

# %% [markdown]
# SAD meaning Shark Attack Data
# # 3. SHOW DATA SET

# %%
sad.head()
# Out:
#     Case Number         Date    Year        Type      Country  \
# 0    2020.02.05  05-Feb-2020  2020.0  Unprovoked          USA
# 1  2020.01.30.R  30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2    2020.01.17  17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3    2020.01.16  16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4    2020.01.13  13-Jan-2020  2020.0  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                    NaN  Stand-Up Paddle boarding
# 1           Exumas                    NaN                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# 3        Southland            Oreti Beach                   Surfing
# 4   North Carolina  Rodanthe, Dare County                   Surfing
#
#               Name Gender  ...                      Species  \
# 0              NaN    NaN  ...                  Tiger shark
# ...

# %%
for index, row in sad.iterrows():
    print(index,row['Country'])
# Out:
# 0 USA
# 1 BAHAMAS
# 2 AUSTRALIA
# 3 NEW ZEALAND
# 4 USA
# 5 THAILAND
# 6 AUSTRALIA
# 7 AUSTRALIA
# 8 NEW CALEDONIA
# 9 AUSTRALIA
# 10 AUSTRALIA
# 11 SEYCHELLES
# 12 PAPUA NEW GUINEA
# 13 SOUTH AFRICA
# 14 NEW ZEALAND
# 15 USA
# 16 AUSTRALIA
# 17 REUNION ISLAND
# 18 AUSTRALIA
# 19 USA
# 20 USA
# 21 AUSTRALIA
# 22 AUSTRALIA
# 23 MEXICO
# 24 ISRAEL
# 25 FRENCH POLYNESIA
# 26 USA
# 27 MEXICO
# 28 SOUTH AFRICA
# 29 REUNION ISLAND
# 30 AUSTRALIA
# 31 USA
# 32 FRENCH POLYNESIA
# 33 AUSTRALIA
# 34 USA
# 35 AUSTRALIA
# 36 USA
# 37 USA
# 38 AUSTRALIA
# 39 USA
# 40 USA
# 41 USA
# 42 USA
# 43 USA
# 44 AUSTRALIA
# 45 USA
# 46 USA
# 47 USA
# 48 USA
# 49 USA
# 50 USA
# 51 USA
# 52 USA
# 53 USA
# 54 USA
# 55 USA
# 56 USA
# 57 USA
# 58 AUSTRALIA
# 59 USA
# 60 USA
# 61 USA
# 62 USA
# 63 NEW ZEALAND
# 64 USA
# 65 USA
# 66 SOUTH AFRICA
# 67 AUSTRALIA
# 68 MEXICO
# 69 BAHAMAS
# 70 USA
# 71 BAHAMAS
# 72 USA
# 73 USA
# 74 USA
# 75 AUSTRALIA
# 76 AUSTRALIA
# 77 USA
# 78 NEW CALEDONIA
# 79 USA
# ...

# %% [markdown]
# Showing data set with swimming as being priority

# %%
sad.loc[sad['Activity'] == "Swimming"]
# Out:
#        Case Number                Date    Year        Type  \
# 5       2020.01.12         12-Jan-2020  2020.0  Unprovoked
# 6       2020.01.07         07-Jan-2020  2020.0  Unprovoked
# 10      2019.12.30         30-Dec-2019  2019.0  Unprovoked
# 11      2019.12.28         28-Dec-2019  2019.0  Unprovoked
# 40    2019.09.24.b         24-Sep-2019  2019.0  Unprovoked
# ...            ...                 ...     ...         ...
# 6447       ND.0014  Before 17-Jul-1916     0.0  Unprovoked
# 6450       ND.0011         Before 1911     0.0  Unprovoked
# 6455       ND.0006         Before 1906     0.0  Unprovoked
# 6458       ND.0003           1900-1905     0.0  Unprovoked
# 6460       ND.0001           1845-1853     0.0  Unprovoked
#
#                  Country                Area  \
# 5               THAILAND  Phang Nga Province
# 6              AUSTRALIA          Queensland
# 10             AUSTRALIA          Queensland
# 11            SEYCHELLES             Praslin
# ...

# %%
# This allows you to sort data quickly, sorting by Country first then area. Then making country in ascending alphabet order and Area decending
sad.sort_values(['Country', 'Area'], ascending=[1,0])
# Out:
#        Case Number                  Date    Year          Type  \
# 3941    1962.10.15           15-Oct-1962  1962.0    Unprovoked
# 6208  1846.09.30.R  Reported 30-Sep-1846  1846.0    Unprovoked
# 6217  1844.07.16.R          1844.07.16.R  1844.0    Unprovoked
# 4285    1958.12.12   1958-12-12 00:00:00  1958.0    Unprovoked
# 4440    1955.08.08   1955-08-08 00:00:00  1955.0    Unprovoked
# ...            ...                   ...     ...           ...
# 6324  1638.00.00.R         Reported 1638  1638.0    Unprovoked
# 6330    1555.00.00                  1555  1555.0    Unprovoked
# 6358       ND-0124           Before 2011     0.0      Provoked
# 6365       ND-0114           Before 2012     0.0    Unprovoked
# 6418       ND.0044             1941-1945     0.0  Sea Disaster
#
#                 Country            Area  \
# 3941  ADMIRALTY ISLANDS    Manus Island
# 6208             AFRICA             NaN
# 6217            ALGERIA             NaN
# 4285     AMERICAN SAMOA  Tutuila Island
# ...

# %%
#sad.Species.value_counts().plot(kind="bar")

# %% [markdown]
# # 4. Filtering Data

# %%
# & means and while | means or
sad.loc[(sad['Country'] == 'AUSTRALIA') & (sad['Area'] == 'New South Wales')]
# Out:
#        Case Number                   Date    Year        Type    Country  \
# 2       2020.01.17            17-Jan-2020  2020.0  Unprovoked  AUSTRALIA
# 16      2019.12.20            20-Dec-2019  2019.0    Provoked  AUSTRALIA
# 35    2019.10.05.b            05-Oct-2019  2019.0  Unprovoked  AUSTRALIA
# 76      2019.06.05            05-Jun-2019  2019.0  Unverified  AUSTRALIA
# 86    2019.04.27.R  27-Apr-2019 Reported   2019.0  Unprovoked  AUSTRALIA
# ...            ...                    ...     ...         ...        ...
# 6294    1791.00.00                   1791  1791.0  Unprovoked  AUSTRALIA
# 6295    1788.05.10            10-May-1788  1788.0  Watercraft  AUSTRALIA
# 6335    0005.00.00             Ca. 5 A.D.     5.0  Unprovoked  AUSTRALIA
# 6436       ND.0025            Before 1927     0.0  Unprovoked  AUSTRALIA
# 6455       ND.0006            Before 1906     0.0  Unprovoked  AUSTRALIA
#
#                  Area                        Location      Activity  \
# ...

# %% [markdown]
# ### 4.1 Removing unwanted rows

# %%
sad= sad.drop(sad.index[6328:])
sad.head()
print (sad)
# Out:
#        Case Number                      Date    Year        Type      Country  \
# 0       2020.02.05               05-Feb-2020  2020.0  Unprovoked          USA
# 1     2020.01.30.R               30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2       2020.01.17               17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3       2020.01.16               16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4       2020.01.13               13-Jan-2020  2020.0  Unprovoked          USA
# ...            ...                       ...     ...         ...          ...
# 6323  1642.00.00.b  Late 1600s Reported 1728  1642.0     Invalid       GUINEA
# 6324  1638.00.00.R             Reported 1638  1638.0  Unprovoked          NaN
# 6325  1637.00.00.R             Reported 1637  1637.0  Unprovoked        INDIA
# 6326  1617.00.00.R             Reported 1617  1617.0  Unprovoked        INDIA
# 6327    1642.00.00                      1642  1642.0  Unprovoked          USA
#
# ...

# %% [markdown]
# ### 4.2 Checking for errors

# %%
new_sad = sad[sad['Case Number'].isna()]
print(new_sad)

new_sad.head()
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Gender, Age, Injury, Fatal (Y/N), Time, Species, Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Gender, Age, Injury, Fatal (Y/N), Time, Species, Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]

# %%
#sad = sad.drop(sad.index[[4086, 5645, 6104]])
#print(sad)
#sad = sad.drop(sad.index[[4089, 5648, 6107]])
#print(sad)

# %%
#sad2 = sad[sad['Case Number'].isna()]
#print(sad2)

#sad2.head()

# %% [markdown]
# ### 4.3 Adding month column and making it into intergers

# %%
sad['month'] = sad['Case Number'].str[5:7]
sad['month'] = sad['month'].astype('int')
import calendar 
def monthtostring(x):
    try:
        return calendar.month_name[x]
    except:
        return "unknown"
    

sad['month_name'] = sad.month.apply(monthtostring)

sad.head()
# Out:
#     Case Number         Date    Year        Type      Country  \
# 0    2020.02.05  05-Feb-2020  2020.0  Unprovoked          USA
# 1  2020.01.30.R  30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2    2020.01.17  17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3    2020.01.16  16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4    2020.01.13  13-Jan-2020  2020.0  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                    NaN  Stand-Up Paddle boarding
# 1           Exumas                    NaN                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# 3        Southland            Oreti Beach                   Surfing
# 4   North Carolina  Rodanthe, Dare County                   Surfing
#
#               Name Gender  ... Case Number.2 original order Unnamed: 22  \
# 0              NaN    NaN  ...           NaN            NaN         NaN
# ...

# %% [markdown]
# ### 4.4 Checking for Nan

# %%
sad3 = sad[sad['Month'].isna()]
print(sad3)

sad3.head()
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Gender, Age, Injury, Fatal (Y/N), Time, Species, Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23, Month]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Gender, Age, Injury, Fatal (Y/N), Time, Species, Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23, Month]
# Index: []
#
# [0 rows x 25 columns]

# %%
results= sad.groupby('Month').sum()

# %%
sad[['First name','Last name']] = sad['Name'].loc[sad['Name'].str.split().str.len() == 2].str.split(expand=True)

#sad['First name'] = sad['First name'].replace(to_replace='Mr.', value='None')
sad['First name'] = sad['First name'].replace('Mr.', np.NaN)
sad['First name'] = sad['First name'].replace('2', np.NaN)
sad['First name'] = sad['First name'].replace('a', np.NaN)

sad.head()
# Out:
#     Case Number         Date    Year        Type      Country  \
# 0    2020.02.05  05-Feb-2020  2020.0  Unprovoked          USA
# 1  2020.01.30.R  30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2    2020.01.17  17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3    2020.01.16  16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4    2020.01.13  13-Jan-2020  2020.0  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                    NaN  Stand-Up Paddle boarding
# 1           Exumas                    NaN                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# 3        Southland            Oreti Beach                   Surfing
# 4   North Carolina  Rodanthe, Dare County                   Surfing
#
#               Name Gender  ...  \
# 0              NaN    NaN  ...
# 1  Ana Bruna Avila      F  ...
# 2   Will Schroeter      M  ...
# 3      Jordan King      F  ...
# ...

# %% [markdown]
# ### 4.5 Creating a graph showing the number of shark attacks per month
#
# Need to make 00 into Na and making each number correlate with a month

# %%
#name_count = sad.groupby("First name").count().Date.sort_values()
#name_count[name_count > 30].plot(kind="barh")

#plt.show()

# %%
Months_count = sad.month_name.value_counts()
Months_count[Months_count > 1].plot(kind="bar")
plt.show()

# %% [markdown]
# # 5. THE HISTORY BEHIND SHARK ATTACKS
# <font color='green'>LOOK AT HOW THERE IS AN INCREASE AROUND 1958-1960's, WHY? INVESTIGATE THIS!</font>

# %%
#plt.line(sad["Year"], color='#0b84a5')


#plt.show()

# %% [markdown]
# ### 5.1 countries with the most shark attacks

# %%
filte1_sad = sad.drop(sad.index[4655:])
filtered_sad= filte1_sad.drop(filte1_sad.index[0:3203])
print(filtered_sad)
# Out:
#        Case Number         Date    Year        Type        Country  \
# 3203    1980.12.30   12-30-1980  1980.0  Unprovoked   SOUTH AFRICA
# 3204    1980.12.26  26-Dec-1980  1980.0     Invalid   SOUTH AFRICA
# 3205    1980.11.24  24-Nov-1980  1980.0  Unprovoked        REUNION
# 3206    1980.11.18  18-Nov-1980  1980.0  Unprovoked      AUSTRALIA
# 3207    1980.11.17  17-Nov-1980  1980.0     Invalid   SOUTH AFRICA
# ...            ...          ...     ...         ...            ...
# 4650  1950.00.00.e  Summer 1950  1950.0  Unprovoked         GREECE
# 4651  1950.00.00.d         1950  1950.0  Unprovoked      SINGAPORE
# 4652  1950.00.00.c         1950  1950.0  Unprovoked  NEW CALEDONIA
# 4653  1950.00.00.b     Ca. 1950  1950.0  Unprovoked  NEW CALEDONIA
# 4654  1950.00.00.a     Ca. 1950  1950.0  Unprovoked           FIJI
#
#                        Area                   Location  \
# 3203  Eastern Cape Province                     Nahoon
# ...

# %%
def countrieswithover100():

    country_count = filtered_sad.groupby("Country").count().Date.sort_values()
    country_count[country_count > 50].plot(kind="barh")

    plt.title('Countries with over 100 shark attacks in total', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
    plt.xlabel('Country', fontdict={'fontname': 'Arial', 'fontsize':14})
    plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

    plt.show()

# %%
countrieswithover100()

# %%
attack_set = set(filtered_sad.Country.unique())

# %%
landlocked_set = pd.read_html('https://en.wikipedia.org/wiki/Landlocked_country')[1].Country['Internationally recognized landlocked countries']

# %%
import re

regex = r"\[.\]"

subst = ""

landlocked_set= set([re.sub(regex, subst, x.upper(), 0, re.MULTILINE) for x in landlocked])

# %%
landlocked_set
# Out:
# {'AFGHANISTAN',
#  'ANDORRA',
#  'ARMENIA',
#  'ARTSAKH',
#  'AUSTRIA',
#  'AZERBAIJAN',
#  'BELARUS',
#  'BHUTAN',
#  'BOLIVIA',
#  'BOTSWANA',
#  'BURKINA FASO',
#  'BURUNDI',
#  'CENTRAL AFRICAN REPUBLIC',
#  'CHAD',
#  'CZECHIA',
#  'ESWATINI',
#  'ETHIOPIA',
#  'HUNGARY',
#  'KAZAKHSTAN',
#  'KOSOVO',
#  'KYRGYZSTAN',
#  'LAOS',
#  'LESOTHO',
#  'LIECHTENSTEIN',
#  "LUHANSK PEOPLE'S REPUBLIC",
#  'LUXEMBOURG',
#  'MALAWI',
#  'MALI',
#  'MOLDOVA',
#  'MONGOLIA',
#  'NEPAL',
#  'NIGER',
#  'NORTH MACEDONIA',
#  'PARAGUAY',
#  'PARTIALLY RECOGNIZED LANDLOCKED STATES',
#  'PERCENTAGE OF THE WORLD',
#  'RWANDA',
#  'SAN MARINO',
#  'SERBIA',
#  'SLOVAKIA',
#  'SOUTH OSSETIA',
#  'SOUTH SUDAN',
#  'SWITZERLAND',
#  'TAJIKISTAN',
#  'TOTAL',
#  'TRANSNISTRIA',
#  'TURKMENISTAN',
#  'UGANDA',
#  'UZBEKISTAN',
#  'VATICAN CITY',
#  'ZAMBIA',
#  'ZIMBABWE'}

# %%
attack_set.intersection(landlocked_set)
# Out:
# set()

# %%
sad[(sad.Country == "USA") & (sad.Year < 2020) & (sad.Year > 1900)].groupby("Year").count().Date.plot()
sad[(sad.Country == "AUSTRALIA") & (sad.Year < 2020) & (sad.Year > 1900)].groupby("Year").count().Date.plot()
sad[(sad.Country == "SOUTH AFRICA") & (sad.Year < 2020) & (sad.Year > 1900)].groupby("Year").count().Date.plot()

plt.title('Number of Shark attacks in USA, Australia & South Africa between 1800-2020', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
plt.xlabel('Year', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

plt.legend(['USA', 'Australia', 'South Africa'])
plt.tight_layout()
plt.show()

# %% [markdown]
# The year since the 1950s; particularly for surfers, snorkelers and SCUBA divers who can enter the water at any time of the year and extend the time they spend in the water in areas that, in earlier decades, were likely to be too cold for recreational purposes

# %%
def countryattacks40to80():

    usa= sad[(sad.Country == "USA") & (sad.Year < 1980) & (sad.Year > 1940)].groupby("Year").count().Date.plot()
    aus= sad[(sad.Country == "AUSTRALIA") & (sad.Year < 1980) & (sad.Year > 1940)].groupby("Year").count().Date.plot()
    sa= sad[(sad.Country == "SOUTH AFRICA") & (sad.Year < 1980) & (sad.Year > 1940)].groupby("Year").count().Date.plot()

    plt.title('Number of Shark attacks in USA, Australia & South Africa between 1940 & 1980', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
    plt.xlabel('Year', fontdict={'fontname': 'Arial', 'fontsize':14})
    plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

    plt.tight_layout()

    plt.legend(['USA', 'Australia', 'South Africa'])
    plt.show()

# %% [markdown]
# https://www.floridamuseum.ufl.edu/science/how-a-century-of-fear-turned-deadly-for-sharks/

# %% [markdown]
# <font color='Red'>LOOK AT THE RISE IN ACTIVITIES SINCE 1960's and see if this correlates with the date and stament said before!</font>

# %% [markdown]
# More people started to recover after the war (1945) and people began to go back to living, going on holidays and travelling to coastal areas.
#
# An increase in the fishin industry in the 1960's

# %% [markdown]
# ### 5.2 What activities were people doing at this time?

# %%
occur = filtered_sad.groupby(['Activity']).size()
print (occur)
# Out:
# Activity
# "Climbing up to ship after repairing the stern in water"             1
# "Flying Tiger" transport plane went down with 5 men onboard          2
# 17 Maldivians adrift in open boat for 31 days                        1
# 25-foot cabin cruiser Happy Jack sank in heavy seas                  1
# 3 men & 2 boys picked up wearing life jackets and with inner tube    1
#                                                                     ..
# canoeing                                                             1
# cargo ship Southern Isle sank at 04h00                               1
# preparing to go skin diving                                          1
# ship M.V. Rizal sank during typhoon                                  1
# wreck of the State Oil Company ship Permina                          1
# Length: 508, dtype: int64

# %%
def pieact40to80():
    occur[occur > 20].plot(kind="pie", subplots=True, autopct="%.1f%%", colors = ['#3f9f7f', '#0b84a5', '#346d94', '#4a9293', '#b8e2ff', '#e4f0ed', '#8dbec9'])
    plt.title('What were people doing in the water between 1940 & 1980?', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')

    plt.ylabel("")
    plt.show()

# %%
#def activityoverview1():
    #usa= sad[(sad.Activity == "Swimming") & (sad.Year < 1980) & (sad.Year > 1940)].groupby("Year").count().Date.plot(color='#C0E0DE')
   # aus= sad[(sad.Activity == "Spearfishing") & (sad.Year < 1980) & (sad.Year > 1940)].groupby("Year").count().Date.plot(color='#16262E')
    #sa= sad[(sad.Activity == "Fishing") & (sad.Year < 1980) & (sad.Year > 1940)].groupby("Year").count().Date.plot(color='#0b84a5')

    #plt.title('Number of Shark attacks in USA, Australia & South Africa between 1950-1980', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
    #plt.xlabel('Year', fontdict={'fontname': 'Arial', 'fontsize':14})
   # plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

    #plt.tight_layout()

   # plt.legend(['Swimming', 'Spearfishing', 'Fishing'])

    #plt.show()

# %%
#x = np.arange(0,10,0.1)
#y = np.arange(10,20,0.1)

#create plot of values
#plt.plot(x,y)

#fill in area between the two lines
#plt.fill_betweenx(y, 2, 4, color='red', alpha=.5)

# %%
def activityoverview1():
    usa= sad[(sad.Activity == "Swimming") & (sad.Year < 1980) & (sad.Year > 1940)].groupby("Year").count().Date.plot(color='#8588a9')
    aus= sad[(sad.Activity == "Spearfishing") & (sad.Year < 1980) & (sad.Year > 1940)].groupby("Year").count().Date.plot(color='#16262E')
    sa= sad[(sad.Activity == "Fishing") & (sad.Year < 1980) & (sad.Year > 1940)].groupby("Year").count().Date.plot(color='#0b84a5')

    plt.title('Number of Shark attacks in USA, Australia & South Africa between 1950-1980', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
    plt.xlabel('Year', fontdict={'fontname': 'Arial', 'fontsize':14})
    plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

    plt.tight_layout()

    plt.axvspan(1958, 1963, color='#b8e3ff', alpha=0.7)
    plt.axvspan(1975, 1977, color='#b8e3ff', alpha=0.7)

    plt.legend(['Swimming', 'Spearfishing', 'Fishing'])

    plt.show()

# %%
activityoverview1()

# %%
def activityoverview2():
    usa= sad[(sad.Activity == "Swimming") & (sad.Year < 1980) & (sad.Year > 1973)].groupby("Year").count().Date.plot(color='#C0E0DE')
    aus= sad[(sad.Activity == "Spearfishing") & (sad.Year < 1980) & (sad.Year > 1973)].groupby("Year").count().Date.plot(color='#16262E')
    sa= sad[(sad.Activity == "Fishing") & (sad.Year < 1980) & (sad.Year > 1973)].groupby("Year").count().Date.plot(color='#0b84a5')

    plt.title('Number of Shark attacks in USA, Australia & South Africa between 1950-1980', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
    plt.xlabel('Year', fontdict={'fontname': 'Arial', 'fontsize':14})
    plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

    plt.tight_layout()
    
    plt.vlines(1975.9, 1, 9, linestyles ="dotted", colors ="#a0a1a5")

    plt.legend(['Swimming', 'Spearfishing', 'Fishing'])
    plt.annotate('Movie Jaws realesed', (1975.96,4.5), rotation='vertical', color= '#565656')

    plt.show()

# %%
activityoverview2()

# %%
def closeupof
usa= sad[(sad.Activity == "Swimming") & (sad.Year < 1980) & (sad.Year > 1973)].groupby("Year").count().Date.plot(color='#C0E0DE')
aus= sad[(sad.Activity == "Spearfishing") & (sad.Year < 1980) & (sad.Year > 1973)].groupby("Year").count().Date.plot(color='#16262E')
sa= sad[(sad.Activity == "Fishing") & (sad.Year < 1980) & (sad.Year > 1973)].groupby("Year").count().Date.plot(color='#0b84a5')

plt.title('Number of Shark attacks in USA, Australia & South Africa between 1950-1980', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
plt.xlabel('Year', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

plt.tight_layout()

plt.legend(['Swimming', 'Spearfishing', 'Fishing'])
    
plt.annotate('Jaws released', xy =(1975,3),
                xytext =(1975.95,5),
                rotation = 'vertical')

#plt.annotate('Jaws released', xy =(1975,3),
              #  xytext =(1975.3,5),
               # rotation = 'vertical',
              #  arrowprops = dict(facecolor ='green',
                      #            arrowstyle="->"))

plt.vlines(1975.9, 1, 9, color='#b6d0e1', linestyles= 'dashed')
 

plt.show()

# %% [markdown]
# ### 5.3 were these attack fatal?

# %% [markdown]
# ### 5.3 Who was being attacked?

# %%
name_count = filte1_sad.groupby("First name").count().Date.sort_values()
name_count[name_count > 23].plot(kind="barh")

fig, ax2 = plt.subplots()
ax2.grid(axis='x')

plt.show()

# %% [markdown]
# 1,298 - Counting the N and Y attacks only =11% were fatal 24% were fatal

# %%
fatal40_80 = filtered_sad.groupby(['Fatal (Y/N)']).size()
print (fatal40_80)
# Out:
# Fatal (Y/N)
# N          980
# UNKNOWN     26
# Y          322
# dtype: int64

# %% [markdown]
# # 6. SHARK ATTACKS NOW 80-2020

# %%
filte2_sad = sad.drop(sad.index[3202:])
print(filte2_sad)
# Out:
#        Case Number         Date    Year        Type       Country  \
# 0       2020.02.05  05-Feb-2020  2020.0  Unprovoked           USA
# 1     2020.01.30.R  30-Jan-2020  2020.0    Provoked       BAHAMAS
# 2       2020.01.17  17-Jan-2020  2020.0  Unprovoked     AUSTRALIA
# 3       2020.01.16  16-Jan-2020  2020.0  Unprovoked   NEW ZEALAND
# 4       2020.01.13  13-Jan-2020  2020.0  Unprovoked           USA
# ...            ...          ...     ...         ...           ...
# 3197    1981.02.02  02-Feb-1981  1981.0  Unprovoked           USA
# 3198    1981.02.00     Feb-1981  1981.0  Unprovoked        BRAZIL
# 3199    1981.01.30  30-Jan-1981  1981.0  Unprovoked           USA
# 3200    1981.01.01  01-Jan-1981  1981.0     Invalid  SOUTH AFRICA
# 3201  1981.00.00.b         1981  1981.0  Unprovoked     AUSTRALIA
#
#                  Area                       Location  \
# 0                Maui                            NaN
# 1              Exumas                            NaN
# ...

# %%
country_count = filte2_sad.groupby("Country").count().Date.sort_values()
country_count[country_count > 50].plot(kind="barh")

plt.title('Countries with over 50 shark attacks in total 1980 - 2020', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
plt.xlabel('Country', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

plt.show()

# %%
def countryattacks80to20():
    usa= sad[(sad.Country == "USA") & (sad.Year < 2020) & (sad.Year > 1980)].groupby("Year").count().Date.plot()
    aus= sad[(sad.Country == "AUSTRALIA") & (sad.Year < 2020) & (sad.Year > 1980)].groupby("Year").count().Date.plot()
    sa= sad[(sad.Country == "SOUTH AFRICA") & (sad.Year < 2020) & (sad.Year > 1980)].groupby("Year").count().Date.plot()

    plt.title('Number of Shark attacks in USA, Australia & South Africa between 1980 & 2020', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
    plt.xlabel('Year', fontdict={'fontname': 'Arial', 'fontsize':14})
    plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

    plt.tight_layout()

    plt.legend(['USA', 'Australia', 'South Africa'])
    plt.show()

# %%
new_occurances = filte2_sad.groupby(['Activity']).size()
new_occurances.head()
# Out:
# Activity
# "Riding waves on a board"                                                                                             1
# 14 m prawn trawler New Venture capsized & sank in heavy seas Three people in the water                                1
# 16' catamaran capsized previous night, occupants stayed with wreckage until morning, then attempted to swim ashore    1
# 2 boats capsized                                                                                                      1
# Abalone diving                                                                                                        1
# dtype: int64

# %%
def pieact80to20():

    new_occurances[new_occurances > 10].plot(kind="pie", subplots=True, autopct="%.1f%%", colors = ['#3f9f7f', '#0b84a5', '#346d94', '#4a9293', '#b8e2ff', '#e4f0ed', '#8dbec9'])
    plt.title('What were people doing in the water between 1980 & 2020?', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')

    plt.ylabel("")
    plt.show()

# %%
#80
new_occurances[new_occurances > 50].plot(kind="pie", subplots=True, autopct="%.1f%%", colors = ['#3f9f7f', '#0b84a5', '#346d94', '#4a9293', '#b8e2ff', '#e4f0ed', '#8dbec9'])
plt.title('What were people doing in the water between 1940 & 1980?', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')

plt.ylabel("")
plt.show()

# %%
acts = filte2_sad[filte2_sad['Activity'] == 'Surfing']
plt.plot(acts.Year, acts.value_counts())
acts.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [270], in <cell line: 2>()
#       1 acts = filte2_sad[filte2_sad['Activity'] == 'Surfing']
# ----> 2 plt.plot(acts.Year, acts.value_counts())
#       3 acts.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
sad[(sad.Activity == "Swimming") & (sad.Year < 2020) & (sad.Year > 1980)].groupby("Year").count().Date.plot(color='#C0E0DE')
sad[(sad.Activity == "Spearfishing") & (sad.Year < 2020) & (sad.Year > 1980)].groupby("Year").count().Date.plot(color='#16262E')
sad[(sad.Activity == "Fishing") & (sad.Year < 2020) & (sad.Year > 1980)].groupby("Year").count().Date.plot(color='#0b84a5')
sad[(sad.Activity == "Surfing") & (sad.Year < 2020) & (sad.Year > 1980)].groupby("Year").count().Date.plot(color='g')

plt.title('Number of Shark attacks in USA, Australia & South Africa between 1950-1980', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
plt.xlabel('Year', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

plt.tight_layout()

plt.legend(['Swimming', 'Spearfishing', 'Fishing', 'Surfing'])

plt.show()

# %%
fatal80_2020 = filte2_sad.groupby(['Fatal (Y/N)']).size()
print (fatal80_2020)
# Out:
# Fatal (Y/N)
# N          2621
# UNKNOWN      31
# Y           326
# dtype: int64

# %%
name_count = filte2_sad.groupby("First name").count().Date.sort_values()
name_count[name_count > 19].plot(kind="barh")

fig, ax2 = plt.subplots()
ax2.grid(axis='x')

plt.show()

# %%
filte2_sad['Fatal (Y/N)'].value_counts()
filte2_sad['Fatal (Y/N)'].value_counts()
# Out:
# N          2621
# Y           326
# UNKNOWN      31
# Name: Fatal (Y/N), dtype: int64

# %% [markdown]
# 2,978 - Counting the N and Y attacks only =11% were fatal

# %%
namedeathoccur = filte2_sad.groupby(['First name', 'Fatal (Y/N)']).size()
namedeathoccur.head()
# Out:
# First name  Fatal (Y/N)
# 12          N              1
# 3           Y              1
# 31          Y              1
# 4           N              1
#             Y              2
# dtype: int64

# %%
#namedeathoccur.plot(kind='bar', stacked=True)

namedeathoccur[namedeathoccur > 19].plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='First name,Fatal (Y/N)'>

# %%
filte2_sad['Fatal (Y/N)'].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ORDER OF GRAPHS

# %%
countryattacks40to80()

# %%
countryattacks80to20()

# %%
pieact40to80()

# %%
pieact80to20()

# %% [markdown]
# ___
#
# <font color='orange'>ALL CODE BELOW IS RUBBISH JUST TESTING DIFFERENT THINGS!</font>

# %%
country_count = sad[(sad.Year < 2020) & (sad.Year > 1990)].groupby("Activity").count().Date.sort_values()
country_count[country_count > 30].plot(kind="bar") 

plt.title('Most common water based activities between 1990-2020', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
plt.xlabel('Activity', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

plt.show()

# %%
species_count = sad.groupby("Species").count().Date.sort_values()
species_count[species_count > 40].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Species'>

# %%
country_count = sad[(sad.Year < 1980) & (sad.Year > 1950)].groupby("Activity").count().Date.sort_values()
country_count[country_count > 30].plot(kind="bar") 

plt.title('Most common water based activities between 1950-1980', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
plt.xlabel('Activity', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

plt.grid()
plt.show()

# %%
bins = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

plt.hist(sad["Year"], bins=bins, color='#0b84a5')
plt.xticks(bins)

plt.ylabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.xlabel('Year', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.title('Number of shark attacks between 2000-2020', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#0b84a5')
plt.grid(True,color='#bfd2d9')

plt.show()

# %% [markdown]
# - During which months specificly were people being attacked? Summer, winter, etc...
#  / colour code these colours accorddingly so we can clearly differenciate the seasons
#  / Add a lengend/key

# %%
Season_attacks = sad['Country'].value_counts()[:5]
Season_attacks.plot(kind='barh', color='#013954')

plt.title('Where shark attacks are most common', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
plt.xlabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.ylabel('Country', fontdict={'fontname': 'Arial', 'fontsize':14})

plt.show()

# %% [markdown]
# - Where are people being attack the most worldwide?
# / Top 10 list with numbers

# %% [markdown]
# - Looking more in Australia which states have the most attacked

# %% [markdown]
# HOW TO MAKE MONTH SPECIFIC DATA

# %% [markdown]
# - NSW look at a map and findout where /which locations are being attcked

# %% [markdown]
#  HOW DO I NARROW THIS DOWN TO AUSTRALIAN STATE????

# %%
Season_attacks = sad['Area'].value_counts()[:5]
Season_attacks.plot(kind='barh', color='#013954')

plt.title('Where shark attacks are most common', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#013954')
plt.xlabel('Number of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.ylabel('Area', fontdict={'fontname': 'Arial', 'fontsize':14})

plt.show()

# %%
Season_attacks = sad['Type'].value_counts()[:5]
Season_attacks.plot(kind='barh', color='#540101')

plt.title('Cause of shark attacks', fontdict={'fontname': 'Arial', 'fontsize':17, 'fontweight':'bold'}, color='#540101')
plt.xlabel('Cause', fontdict={'fontname': 'Arial', 'fontsize':14})
plt.ylabel('Amount of attacks', fontdict={'fontname': 'Arial', 'fontsize':14})

plt.show()
